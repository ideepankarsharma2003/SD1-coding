# %% [markdown]
# # [**Minimum Sum Partition**](https://practice.geeksforgeeks.org/problems/minimum-sum-partition3317/1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#User function Template for python3
class Solution:
	def subset_sum(self, arr, s, n):
		t= [[False for i in range(s+1)] for j in range(n+1)]
		# i---> n
		# j---> s

		# initialization 
		'''
		* if sum==0, then null set is ans, so return true
		* if n==0 and sum>1, then kuch bhi karlo nhi hoga, so return false
		'''
		for i in range(n+1):
			for j in range(s+1):
				if j==0:
					t[i][j]= True

		for i in range(1, n+1):
			for j in range(1, s+1):
				# last element is greater than sum
				if arr[i-1]>j:
					t[i][j]=t[i-1][j]
				# choice diagram
				else:
					t[i][j]=t[i-1][j] or t[i-1][j-arr[i-1]]

		return t[-1][-1]



	def minDifference(self, arr, n):
		# code here
		s= sum(arr)
		ans= s
		for s1 in range((s//2)+1):
		    if self.subset_sum(arr, s1, n):
				ans= min(ans, abs(s- 2*s1))
		return ans

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#User function Template for python3
class Solution:
	def subset_sum(self, arr, s, n):
		t= [[False for i in range(s+1)] for j in range(n+1)]
		# i---> n
		# j---> s

		# initialization 
		'''
		* if sum==0, then null set is ans, so return true
		* if n==0 and sum>1, then kuch bhi karlo nhi hoga, so return false
		'''
		for i in range(n+1):
			for j in range(s+1):
				if j==0:
					t[i][j]= True

		for i in range(1, n+1):
			for j in range(1, s+1):
				# last element is greater than sum
				if arr[i-1]>j:
					t[i][j]=t[i-1][j]
				# choice diagram
				else:
					t[i][j]=t[i-1][j] or t[i-1][j-arr[i-1]]
		# print(t)
		
		return t[-1] # return last row



	def minDifference(self, arr, n):
		# code here
		s= sum(arr)
		last_row= self.subset_sum(arr, s, n)
		print(last_row)
		ans= s
		for s1 in range(s//2+1):
			if last_row[s1]:
				ans= min(ans, abs(s- 2*s1))
		return ans


s= Solution()

# %%
n= 5
arr= [20, 19, 18, 20, 16]

s.minDifference(arr, n)
# Out:
# [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]
# 13
